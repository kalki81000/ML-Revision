# %% [markdown]
# <a href="https://colab.research.google.com/github/kalki81000/ML-Revision/blob/main/Untitled84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SVM CLASSIFIER

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#reducing the column to reduce the runtime
df = df[['V1' , 'V2' , 'V3' , 'V4' , 'Class']]

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'Class'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V1      284807 non-null  float64
#  1   V2      284807 non-null  float64
#  2   V3      284807 non-null  float64
#  3   V4      284807 non-null  float64
#  4   Class   284807 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 10.9 MB

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4          Class
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15       0.001727
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00       0.041527
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00       0.000000
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01       0.000000
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02       0.000000
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01       0.000000
# max    2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01       1.000000

# %%
df.isna().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# Class    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 9144

# %%
df.drop_duplicates(inplace = True)

# %%
df.Class.value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
df_mjor = df[df.Class == 0]
df_minor = df[df.Class == 1]

# %%
from sklearn.utils import resample
df_mjor =resample(df_mjor , replace = True , n_samples= 10000 , random_state = 1)

# %%
df_mjor.shape
# Out:
# (10000, 5)

# %%
from imblearn.over_sampling import SMOTE
ovs = SMOTE()
x , y = ovs.fit_resample(df.drop('Class' , axis = 1) , df['Class'])

# %%
balance = pd.concat([x , y] , axis = 1)
balance = balance[balance.Class == 1]
df_minor = resample(balance , replace = False , n_samples = 1000 , random_state = 1)

# %%
df
# Out:
#                V1         V2        V3        V4  Class
# 0       -1.359807  -0.072781  2.536347  1.378155      0
# 1        1.191857   0.266151  0.166480  0.448154      0
# 2       -1.358354  -1.340163  1.773209  0.379780      0
# 3       -0.966272  -0.185226  1.792993 -0.863291      0
# 4       -1.158233   0.877737  1.548718  0.403034      0
# ...           ...        ...       ...       ...    ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656      0
# 284803  -0.732789  -0.055080  2.035030 -0.738589      0
# 284804   1.919565  -0.301254 -3.249640 -0.557828      0
# 284805  -0.240440   0.530483  0.702510  0.689799      0
# 284806  -0.533413  -0.189733  0.703337 -0.506271      0
#
# [275663 rows x 5 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                V1         V2        V3        V4  Class
# 0       -1.359807  -0.072781  2.536347  1.378155      0
# 1        1.191857   0.266151  0.166480  0.448154      0
# 2       -1.358354  -1.340163  1.773209  0.379780      0
# 3       -0.966272  -0.185226  1.792993 -0.863291      0
# 4       -1.158233   0.877737  1.548718  0.403034      0
# ...           ...        ...       ...       ...    ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656      0
# 284803  -0.732789  -0.055080  2.035030 -0.738589      0
# 284804   1.919565  -0.301254 -3.249640 -0.557828      0
# 284805  -0.240440   0.530483  0.702510  0.689799      0
# 284806  -0.533413  -0.189733  0.703337 -0.506271      0
#
# [275663 rows x 5 columns]

# %%
df.reset_index(drop = True , inplace = True)

# %%
df
# Out:
#                V1         V2        V3        V4  Class
# 0       -1.359807  -0.072781  2.536347  1.378155      0
# 1        1.191857   0.266151  0.166480  0.448154      0
# 2       -1.358354  -1.340163  1.773209  0.379780      0
# 3       -0.966272  -0.185226  1.792993 -0.863291      0
# 4       -1.158233   0.877737  1.548718  0.403034      0
# ...           ...        ...       ...       ...    ...
# 275658 -11.881118  10.071785 -9.834783 -2.066656      0
# 275659  -0.732789  -0.055080  2.035030 -0.738589      0
# 275660   1.919565  -0.301254 -3.249640 -0.557828      0
# 275661  -0.240440   0.530483  0.702510  0.689799      0
# 275662  -0.533413  -0.189733  0.703337 -0.506271      0
#
# [275663 rows x 5 columns]

# %%
x = df.drop('Class' , axis = 1)
y = df['Class']

# %%
x
# Out:
#                V1         V2        V3        V4
# 0       -1.359807  -0.072781  2.536347  1.378155
# 1        1.191857   0.266151  0.166480  0.448154
# 2       -1.358354  -1.340163  1.773209  0.379780
# 3       -0.966272  -0.185226  1.792993 -0.863291
# 4       -1.158233   0.877737  1.548718  0.403034
# ...           ...        ...       ...       ...
# 275658 -11.881118  10.071785 -9.834783 -2.066656
# 275659  -0.732789  -0.055080  2.035030 -0.738589
# 275660   1.919565  -0.301254 -3.249640 -0.557828
# 275661  -0.240440   0.530483  0.702510  0.689799
# 275662  -0.533413  -0.189733  0.703337 -0.506271
#
# [275663 rows x 4 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 275658    0
# 275659    0
# 275660    0
# 275661    0
# 275662    0
# Name: Class, Length: 275663, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.30 , random_state= 1)

# %%
x_train.shape
# Out:
# (192964, 4)

# %%
x_test.shape
# Out:
# (82699, 4)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train , y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score , confusion_matrix , classification_report
print(accuracy_score(y_test , y_pred))
# Out:
# 0.9988633478034801

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     82554
#            1       0.90      0.39      0.55       145
#
#     accuracy                           1.00     82699
#    macro avg       0.95      0.70      0.77     82699
# weighted avg       1.00      1.00      1.00     82699

# %% [markdown]
# # SVN REGRESSOR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("/content/creditcard.csv")

# %%
df1
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df1 = df1[['V1' ,'V2' , 'V3' , 'V4' , 'Amount']]

# %%
df1.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'Amount'], dtype='object')

# %%
df1 = df1.iloc[:20000]

# %%
df1.shape
# Out:
# (20000, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      20000 non-null  float64
#  1   V2      20000 non-null  float64
#  2   V3      20000 non-null  float64
#  3   V4      20000 non-null  float64
#  4   Amount  20000 non-null  float64
# dtypes: float64(5)
# memory usage: 781.4 KB

# %%
df1.describe()
# Out:
#                  V1            V2            V3            V4        Amount
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      -0.245246      0.240540      0.745642      0.277184     70.415607
# std        1.891443      1.530065      1.767917      1.465185    206.048941
# min      -30.552380    -40.978852    -31.103685     -5.172595      0.000000
# 25%       -0.960386     -0.329136      0.309215     -0.635675      5.800000
# 50%       -0.302521      0.219042      0.898672      0.225051     16.055000
# 75%        1.164501      0.868990      1.532667      1.142537     59.990000
# max        1.960497     16.713389      4.101716     11.927512   7879.420000

# %%
df1.isna().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# Amount    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.drop_duplicates(inplace = True)

# %%
x = df1.drop('Amount' , axis = 1)
y = df1['Amount']

# %%
x
# Out:
#              V1        V2        V3        V4
# 0     -1.359807 -0.072781  2.536347  1.378155
# 1      1.191857  0.266151  0.166480  0.448154
# 2     -1.358354 -1.340163  1.773209  0.379780
# 3     -0.966272 -0.185226  1.792993 -0.863291
# 4     -1.158233  0.877737  1.548718  0.403034
# ...         ...       ...       ...       ...
# 19995 -2.574861 -3.159709 -0.066802 -2.342403
# 19996  1.172969  0.221508  0.622677  0.650761
# 19997 -1.061245  0.721735  0.569426 -0.145278
# 19998 -0.975430 -1.649324  1.581357 -1.379578
# 19999  1.071615  0.013662  1.505439  1.409847
#
# [19433 rows x 4 columns]

# %%
y
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#           ...
# 19995    1200.00
# 19996      12.99
# 19997      60.00
# 19998      15.50
# 19999       9.99
# Name: Amount, Length: 19433, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.30 , random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.svm import SVR
reg = SVR()
reg.fit(x_train , y_train)
# Out:
# SVR()

# %%
y_pre = reg.predict(x_test)

# %%
y_pre
# Out:
# array([40.99709596, 43.1996583 ,  0.06993899, ..., 23.44695677,
#         6.60500351,  2.55416809])

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test , y_pre))
# Out:
# 0.10958373863410908
